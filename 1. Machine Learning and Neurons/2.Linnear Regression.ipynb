# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv")

# %%
data
# Out:
#      1971         2300
# 0    1972         3500
# 1    1973         2500
# 2    1973         2500
# 3    1974         4100
# 4    1974         4500
# ..    ...          ...
# 156  2017  18000000000
# 157  2017  19200000000
# 158  2018   8876000000
# 159  2018  23600000000
# 160  2018   9000000000
#
# [161 rows x 2 columns]

# %%
x =np.array( data.iloc[:, 0]).reshape(-1,1)
y = data.iloc[:, 1]

# %%
y
# Out:
# 0             3500
# 1             2500
# 2             2500
# 3             4100
# 4             4500
#           ...
# 156    18000000000
# 157    19200000000
# 158     8876000000
# 159    23600000000
# 160     9000000000
# Name: 2300, Length: 161, dtype: int64

# %%
plt.scatter(x,y);

# %%
# since we want the linner model , lets take the log
y = np.log(y)
plt.scatter(x,y);
